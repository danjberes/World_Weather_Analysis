# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
longs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_longs = zip(lats, longs)
lat_longs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_longs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL and add API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description=city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nanortalik
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | port augusta
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | hede
# Processing Record 8 of Set 1 | zaraza
# Processing Record 9 of Set 1 | poum
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | gold coast
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | husavik
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | guerrero negro
# Processing Record 19 of Set 1 | sao filipe
# Processing Record 20 of Set 1 | mananjary
# Processing Record 21 of Set 1 | baksanenok
# Processing Record 22 of Set 1 | severo-kurilsk
# Processing Record 23 of Set 1 | sinegorskiy
# Processing Record 24 of Set 1 | kodiak
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | ambovombe
# Processing Record 27 of Set 1 | benguela
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | los llanos de aridane
# Processing Record 31 of Set 1 | praya
# Processing Record 32 of Set 1 | okha
# Processing Record 33 of Set 1 | irbeyskoye
# Processing Record 34 of Set 1 | onega
# Processing Record 35 of Set 1 | manokwari
# Processing Record 36 of Set 1 | vostok
# Processing Record 37 of Set 1 | horconcitos
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | kirkland lake
# Processing Record 40 of Set 1 | lushunkou
# City not found. Skipping...
# Processing Record 41 of Set 1 | tura
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | horta
# Processing Record 48 of Set 1 | beringovskiy
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | airai
# Processing Record 1 of Set 2 | ormenis
# Processing Record 2 of Set 2 | virginia beach
# Processing Record 3 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 2 | karlskoga
# Processing Record 5 of Set 2 | chemax
# Processing Record 6 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 2 | faya
# Processing Record 8 of Set 2 | westport
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | anadyr
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | kristinehamn
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | freeport
# Processing Record 17 of Set 2 | umred
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | bathsheba
# Processing Record 20 of Set 2 | port hardy
# Processing Record 21 of Set 2 | lorengau
# Processing Record 22 of Set 2 | avera
# Processing Record 23 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 2 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 2 | ayan
# Processing Record 26 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 2 | pacific grove
# Processing Record 28 of Set 2 | catamarca
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | laguna
# Processing Record 33 of Set 2 | hithadhoo
# Processing Record 34 of Set 2 | pasinler
# Processing Record 35 of Set 2 | tynda
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | pozo colorado
# Processing Record 38 of Set 2 | kavaratti
# Processing Record 39 of Set 2 | manta
# Processing Record 40 of Set 2 | carnarvon
# Processing Record 41 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 2 | mahenge
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | kamenka
# Processing Record 46 of Set 2 | palmas
# Processing Record 47 of Set 2 | haines junction
# Processing Record 48 of Set 2 | bud
# Processing Record 49 of Set 2 | grand forks
# Processing Record 50 of Set 2 | whitehorse
# Processing Record 1 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 3 | saint-joseph
# Processing Record 3 of Set 3 | santa maria del oro
# Processing Record 4 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 5 of Set 3 | klaksvik
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 3 | raga
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | bayanday
# Processing Record 11 of Set 3 | lagoa
# Processing Record 12 of Set 3 | port keats
# Processing Record 13 of Set 3 | kruisfontein
# Processing Record 14 of Set 3 | hamilton
# Processing Record 15 of Set 3 | alyangula
# Processing Record 16 of Set 3 | asau
# Processing Record 17 of Set 3 | sioux lookout
# Processing Record 18 of Set 3 | tchaourou
# Processing Record 19 of Set 3 | lavrentiya
# Processing Record 20 of Set 3 | panguna
# Processing Record 21 of Set 3 | vila velha
# Processing Record 22 of Set 3 | taoudenni
# Processing Record 23 of Set 3 | bharatpur
# Processing Record 24 of Set 3 | awjilah
# Processing Record 25 of Set 3 | oranjestad
# Processing Record 26 of Set 3 | cockburn town
# Processing Record 27 of Set 3 | alice springs
# Processing Record 28 of Set 3 | sorata
# Processing Record 29 of Set 3 | bonfim
# Processing Record 30 of Set 3 | ponta do sol
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | youkounkoun
# Processing Record 33 of Set 3 | hukuntsi
# Processing Record 34 of Set 3 | goderich
# Processing Record 35 of Set 3 | lazaro cardenas
# Processing Record 36 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 3 | gouyave
# Processing Record 38 of Set 3 | tautira
# Processing Record 39 of Set 3 | komsomolskiy
# Processing Record 40 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 3 | flinders
# Processing Record 42 of Set 3 | avarua
# Processing Record 43 of Set 3 | albany
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | skibbereen
# Processing Record 46 of Set 3 | koshurnikovo
# Processing Record 47 of Set 3 | lasa
# Processing Record 48 of Set 3 | paslek
# Processing Record 49 of Set 3 | nome
# Processing Record 50 of Set 3 | carutapera
# Processing Record 1 of Set 4 | port-gentil
# Processing Record 2 of Set 4 | epernay
# Processing Record 3 of Set 4 | harper
# Processing Record 4 of Set 4 | tual
# Processing Record 5 of Set 4 | badulla
# Processing Record 6 of Set 4 | fort-shevchenko
# Processing Record 7 of Set 4 | praia
# Processing Record 8 of Set 4 | geraldton
# Processing Record 9 of Set 4 | nouadhibou
# Processing Record 10 of Set 4 | nokaneng
# Processing Record 11 of Set 4 | mkushi
# Processing Record 12 of Set 4 | praia da vitoria
# Processing Record 13 of Set 4 | kapaa
# Processing Record 14 of Set 4 | mpraeso
# Processing Record 15 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 16 of Set 4 | santa maria
# Processing Record 17 of Set 4 | lima
# Processing Record 18 of Set 4 | mount isa
# Processing Record 19 of Set 4 | panaba
# Processing Record 20 of Set 4 | tinskoy
# Processing Record 21 of Set 4 | mola di bari
# Processing Record 22 of Set 4 | khatanga
# Processing Record 23 of Set 4 | vila franca do campo
# Processing Record 24 of Set 4 | clyde river
# Processing Record 25 of Set 4 | trat
# Processing Record 26 of Set 4 | upington
# Processing Record 27 of Set 4 | georgetown
# Processing Record 28 of Set 4 | maniitsoq
# Processing Record 29 of Set 4 | ribeira brava
# Processing Record 30 of Set 4 | allapalli
# Processing Record 31 of Set 4 | linjiang
# Processing Record 32 of Set 4 | bredasdorp
# Processing Record 33 of Set 4 | padang
# Processing Record 34 of Set 4 | butaritari
# Processing Record 35 of Set 4 | norman wells
# Processing Record 36 of Set 4 | antalaha
# Processing Record 37 of Set 4 | bethel
# Processing Record 38 of Set 4 | ixtapa
# Processing Record 39 of Set 4 | caorle
# Processing Record 40 of Set 4 | nalut
# Processing Record 41 of Set 4 | pochutla
# Processing Record 42 of Set 4 | nyrob
# Processing Record 43 of Set 4 | muravlenko
# Processing Record 44 of Set 4 | menongue
# Processing Record 45 of Set 4 | gigmoto
# Processing Record 46 of Set 4 | santa catarina de tepehuanes
# Processing Record 47 of Set 4 | derzhavinsk
# Processing Record 48 of Set 4 | evanston
# Processing Record 49 of Set 4 | vanimo
# Processing Record 50 of Set 4 | tuatapere
# Processing Record 1 of Set 5 | general roca
# Processing Record 2 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 5 | aklavik
# Processing Record 4 of Set 5 | touros
# Processing Record 5 of Set 5 | ginir
# Processing Record 6 of Set 5 | arraial do cabo
# Processing Record 7 of Set 5 | ati
# Processing Record 8 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 5 | umm lajj
# Processing Record 10 of Set 5 | osterburg
# Processing Record 11 of Set 5 | itiuba
# Processing Record 12 of Set 5 | zhangye
# Processing Record 13 of Set 5 | ulaanbaatar
# Processing Record 14 of Set 5 | miandrivazo
# Processing Record 15 of Set 5 | evensk
# Processing Record 16 of Set 5 | provideniya
# Processing Record 17 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 5 | chulym
# Processing Record 19 of Set 5 | novomyshastovskaya
# Processing Record 20 of Set 5 | manbij
# Processing Record 21 of Set 5 | faanui
# Processing Record 22 of Set 5 | imeni zhelyabova
# Processing Record 23 of Set 5 | jasdan
# Processing Record 24 of Set 5 | cervo
# Processing Record 25 of Set 5 | hare bay
# Processing Record 26 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 5 | mayo
# Processing Record 29 of Set 5 | ribeira grande
# Processing Record 30 of Set 5 | lebu
# Processing Record 31 of Set 5 | paamiut
# Processing Record 32 of Set 5 | saint-augustin
# Processing Record 33 of Set 5 | sakaiminato
# Processing Record 34 of Set 5 | barcelos
# Processing Record 35 of Set 5 | torrox
# Processing Record 36 of Set 5 | marrakesh
# Processing Record 37 of Set 5 | ardmore
# Processing Record 38 of Set 5 | wana
# Processing Record 39 of Set 5 | acapulco
# Processing Record 40 of Set 5 | champerico
# Processing Record 41 of Set 5 | dunedin
# Processing Record 42 of Set 5 | tasiilaq
# Processing Record 43 of Set 5 | mount gambier
# Processing Record 44 of Set 5 | marondera
# Processing Record 45 of Set 5 | rawson
# Processing Record 46 of Set 5 | williston
# Processing Record 47 of Set 5 | thibodaux
# Processing Record 48 of Set 5 | tarauaca
# Processing Record 49 of Set 5 | wanaka
# Processing Record 50 of Set 5 | huarmey
# Processing Record 1 of Set 6 | dikson
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | kangaatsiaq
# Processing Record 4 of Set 6 | rio grande
# Processing Record 5 of Set 6 | aksarka
# Processing Record 6 of Set 6 | lensk
# Processing Record 7 of Set 6 | vardo
# Processing Record 8 of Set 6 | vredendal
# Processing Record 9 of Set 6 | comodoro rivadavia
# Processing Record 10 of Set 6 | ngunguru
# Processing Record 11 of Set 6 | palana
# Processing Record 12 of Set 6 | salalah
# Processing Record 13 of Set 6 | rocha
# Processing Record 14 of Set 6 | muzhi
# Processing Record 15 of Set 6 | utiel
# Processing Record 16 of Set 6 | atar
# Processing Record 17 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 18 of Set 6 | atuona
# Processing Record 19 of Set 6 | chilca
# Processing Record 20 of Set 6 | lufilufi
# Processing Record 21 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 6 | hambantota
# Processing Record 23 of Set 6 | yangambi
# Processing Record 24 of Set 6 | caravelas
# Processing Record 25 of Set 6 | mandera
# Processing Record 26 of Set 6 | upernavik
# Processing Record 27 of Set 6 | simga
# Processing Record 28 of Set 6 | karasburg
# Processing Record 29 of Set 6 | moose factory
# Processing Record 30 of Set 6 | sitka
# Processing Record 31 of Set 6 | staraya toropa
# Processing Record 32 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 33 of Set 6 | myitkyina
# Processing Record 34 of Set 6 | sfantu gheorghe
# Processing Record 35 of Set 6 | sorong
# Processing Record 36 of Set 6 | zakharovo
# Processing Record 37 of Set 6 | acarau
# Processing Record 38 of Set 6 | pointe-noire
# Processing Record 39 of Set 6 | katsuura
# Processing Record 40 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 6 | souillac
# Processing Record 42 of Set 6 | mayor pablo lagerenza
# Processing Record 43 of Set 6 | rio gallegos
# Processing Record 44 of Set 6 | kirakira
# Processing Record 45 of Set 6 | higuey
# City not found. Skipping...
# Processing Record 46 of Set 6 | rancho palos verdes
# Processing Record 47 of Set 6 | natal
# Processing Record 48 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 6 | chokurdakh
# Processing Record 50 of Set 6 | hovd
# Processing Record 1 of Set 7 | cuddapah
# Processing Record 2 of Set 7 | erzin
# Processing Record 3 of Set 7 | beaumont
# Processing Record 4 of Set 7 | kahului
# Processing Record 5 of Set 7 | tver
# Processing Record 6 of Set 7 | havelock
# Processing Record 7 of Set 7 | umea
# Processing Record 8 of Set 7 | arroyo
# Processing Record 9 of Set 7 | le port
# Processing Record 10 of Set 7 | mujiayingzi
# Processing Record 11 of Set 7 | esperance
# Processing Record 12 of Set 7 | karratha
# Processing Record 13 of Set 7 | port lincoln
# Processing Record 14 of Set 7 | oxbow
# Processing Record 15 of Set 7 | kidal
# Processing Record 16 of Set 7 | pinega
# Processing Record 17 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 7 | chumikan
# Processing Record 19 of Set 7 | sanary-sur-mer
# Processing Record 20 of Set 7 | leningradskiy
# Processing Record 21 of Set 7 | kozhevnikovo
# Processing Record 22 of Set 7 | buala
# Processing Record 23 of Set 7 | belaya gora
# Processing Record 24 of Set 7 | sukhumi
# Processing Record 25 of Set 7 | el jicaro
# Processing Record 26 of Set 7 | finschhafen
# Processing Record 27 of Set 7 | sao lourenco do sul
# Processing Record 28 of Set 7 | sabha
# Processing Record 29 of Set 7 | tilichiki
# Processing Record 30 of Set 7 | novo aripuana
# Processing Record 31 of Set 7 | yaval
# Processing Record 32 of Set 7 | lusambo
# Processing Record 33 of Set 7 | ahipara
# Processing Record 34 of Set 7 | quang ngai
# Processing Record 35 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 36 of Set 7 | hofn
# Processing Record 37 of Set 7 | sao joao da barra
# Processing Record 38 of Set 7 | coihaique
# Processing Record 39 of Set 7 | cabo san lucas
# Processing Record 40 of Set 7 | gijon
# Processing Record 41 of Set 7 | srednekolymsk
# Processing Record 42 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 43 of Set 7 | auki
# Processing Record 44 of Set 7 | kutum
# Processing Record 45 of Set 7 | mahibadhoo
# Processing Record 46 of Set 7 | dingle
# Processing Record 47 of Set 7 | palu
# Processing Record 48 of Set 7 | darhan
# Processing Record 49 of Set 7 | cururupu
# Processing Record 50 of Set 7 | vasterhaninge
# Processing Record 1 of Set 8 | victoria
# Processing Record 2 of Set 8 | madruga
# Processing Record 3 of Set 8 | linfen
# Processing Record 4 of Set 8 | belyy yar
# Processing Record 5 of Set 8 | saint george
# Processing Record 6 of Set 8 | yantal
# Processing Record 7 of Set 8 | castro
# Processing Record 8 of Set 8 | olafsvik
# Processing Record 9 of Set 8 | sao geraldo do araguaia
# Processing Record 10 of Set 8 | kerman
# Processing Record 11 of Set 8 | dubbo
# Processing Record 12 of Set 8 | gao
# Processing Record 13 of Set 8 | torbay
# Processing Record 14 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 8 | fortuna
# Processing Record 16 of Set 8 | rio de janeiro
# Processing Record 17 of Set 8 | volosovo
# Processing Record 18 of Set 8 | gua musang
# Processing Record 19 of Set 8 | namibe
# Processing Record 20 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 21 of Set 8 | caramay
# Processing Record 22 of Set 8 | himare
# Processing Record 23 of Set 8 | pevek
# Processing Record 24 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 8 | nalvo
# Processing Record 26 of Set 8 | kungurtug
# Processing Record 27 of Set 8 | kudahuvadhoo
# Processing Record 28 of Set 8 | ossora
# Processing Record 29 of Set 8 | fairbanks
# Processing Record 30 of Set 8 | amga
# Processing Record 31 of Set 8 | turukhansk
# Processing Record 32 of Set 8 | moroni
# Processing Record 33 of Set 8 | baranain
# Processing Record 34 of Set 8 | half moon bay
# Processing Record 35 of Set 8 | san cristobal
# Processing Record 36 of Set 8 | grezzana
# Processing Record 37 of Set 8 | lamu
# Processing Record 38 of Set 8 | margate
# Processing Record 39 of Set 8 | bayji
# Processing Record 40 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 8 | svetlaya
# Processing Record 42 of Set 8 | yar-sale
# Processing Record 43 of Set 8 | korla
# Processing Record 44 of Set 8 | san andres
# Processing Record 45 of Set 8 | sao joaquim
# Processing Record 46 of Set 8 | molchanovo
# Processing Record 47 of Set 8 | aguimes
# Processing Record 48 of Set 8 | conceicao do araguaia
# Processing Record 49 of Set 8 | fort morgan
# Processing Record 50 of Set 8 | ilulissat
# Processing Record 1 of Set 9 | sale
# Processing Record 2 of Set 9 | manica
# Processing Record 3 of Set 9 | yarim
# Processing Record 4 of Set 9 | nampula
# Processing Record 5 of Set 9 | tombouctou
# Processing Record 6 of Set 9 | fare
# Processing Record 7 of Set 9 | monkey hill
# Processing Record 8 of Set 9 | douentza
# Processing Record 9 of Set 9 | hirara
# Processing Record 10 of Set 9 | sirur
# Processing Record 11 of Set 9 | angoche
# Processing Record 12 of Set 9 | talca
# Processing Record 13 of Set 9 | kieta
# Processing Record 14 of Set 9 | barand
# Processing Record 15 of Set 9 | namatanai
# Processing Record 16 of Set 9 | madras
# Processing Record 17 of Set 9 | high rock
# Processing Record 18 of Set 9 | sawtell
# Processing Record 19 of Set 9 | honiara
# Processing Record 20 of Set 9 | jian
# Processing Record 21 of Set 9 | kjollefjord
# Processing Record 22 of Set 9 | watertown
# Processing Record 23 of Set 9 | calbuco
# Processing Record 24 of Set 9 | homer
# Processing Record 25 of Set 9 | coahuayana
# Processing Record 26 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 9 | asfi
# Processing Record 28 of Set 9 | carlsbad
# Processing Record 29 of Set 9 | hasaki
# Processing Record 30 of Set 9 | tefe
# Processing Record 31 of Set 9 | grand-lahou
# Processing Record 32 of Set 9 | chilliwack
# Processing Record 33 of Set 9 | dhidhdhoo
# Processing Record 34 of Set 9 | bambous virieux
# Processing Record 35 of Set 9 | hasilpur
# Processing Record 36 of Set 9 | morgan city
# Processing Record 37 of Set 9 | gimli
# Processing Record 38 of Set 9 | ketchikan
# Processing Record 39 of Set 9 | mineros
# Processing Record 40 of Set 9 | lata
# Processing Record 41 of Set 9 | dicabisagan
# Processing Record 42 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 9 | tammisaari
# Processing Record 44 of Set 9 | talnakh
# Processing Record 45 of Set 9 | morristown
# Processing Record 46 of Set 9 | alekseyevka
# Processing Record 47 of Set 9 | ancud
# Processing Record 48 of Set 9 | sangar
# Processing Record 49 of Set 9 | marsh harbour
# Processing Record 50 of Set 9 | gizo
# Processing Record 1 of Set 10 | shuangyang
# Processing Record 2 of Set 10 | mitsamiouli
# Processing Record 3 of Set 10 | puerto ayacucho
# Processing Record 4 of Set 10 | taltal
# Processing Record 5 of Set 10 | tiksi
# Processing Record 6 of Set 10 | luocheng
# Processing Record 7 of Set 10 | ocos
# Processing Record 8 of Set 10 | mizan teferi
# Processing Record 9 of Set 10 | cayenne
# Processing Record 10 of Set 10 | silver city
# Processing Record 11 of Set 10 | codrington
# Processing Record 12 of Set 10 | waipawa
# Processing Record 13 of Set 10 | ust-maya
# Processing Record 14 of Set 10 | luderitz
# Processing Record 15 of Set 10 | tarpon springs
# Processing Record 16 of Set 10 | abu kamal
# Processing Record 17 of Set 10 | gacko
# Processing Record 18 of Set 10 | shetpe
# Processing Record 19 of Set 10 | pilas
# Processing Record 20 of Set 10 | lodja
# Processing Record 21 of Set 10 | zolotukhino
# Processing Record 22 of Set 10 | nishihara
# Processing Record 23 of Set 10 | ust-nera
# Processing Record 24 of Set 10 | loiza
# Processing Record 25 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 26 of Set 10 | san patricio
# Processing Record 27 of Set 10 | high level
# Processing Record 28 of Set 10 | nikel
# Processing Record 29 of Set 10 | san policarpo
# Processing Record 30 of Set 10 | narsaq
# Processing Record 31 of Set 10 | toropets
# Processing Record 32 of Set 10 | cabatuan
# Processing Record 33 of Set 10 | la rioja
# Processing Record 34 of Set 10 | ilebo
# Processing Record 35 of Set 10 | hienghene
# Processing Record 36 of Set 10 | minsk mazowiecki
# Processing Record 37 of Set 10 | enumclaw
# Processing Record 38 of Set 10 | savonlinna
# Processing Record 39 of Set 10 | birzai
# Processing Record 40 of Set 10 | bandarbeyla
# Processing Record 41 of Set 10 | constitucion
# Processing Record 42 of Set 10 | am timan
# Processing Record 43 of Set 10 | olenino
# Processing Record 44 of Set 10 | dryden
# Processing Record 45 of Set 10 | mabaruma
# Processing Record 46 of Set 10 | havoysund
# Processing Record 47 of Set 10 | riyadh
# Processing Record 48 of Set 10 | gorontalo
# Processing Record 49 of Set 10 | limoux
# Processing Record 50 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 11 | lavumisa
# Processing Record 2 of Set 11 | mosquera
# Processing Record 3 of Set 11 | dawei
# Processing Record 4 of Set 11 | jati
# Processing Record 5 of Set 11 | te anau
# Processing Record 6 of Set 11 | ardesen
# Processing Record 7 of Set 11 | awbari
# Processing Record 8 of Set 11 | san vicente
# Processing Record 9 of Set 11 | angren
# Processing Record 10 of Set 11 | sandy bay
# Processing Record 11 of Set 11 | maningrida
# Processing Record 12 of Set 11 | daru
# Processing Record 13 of Set 11 | zheshart
# Processing Record 14 of Set 11 | bowen
# Processing Record 15 of Set 11 | mehamn
# Processing Record 16 of Set 11 | meulaboh
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | odweyne
# Processing Record 19 of Set 11 | middelburg
# Processing Record 20 of Set 11 | ambilobe
# Processing Record 21 of Set 11 | olinda
# Processing Record 22 of Set 11 | byron bay
# Processing Record 23 of Set 11 | vestmannaeyjar
# Processing Record 24 of Set 11 | qingyuan
# Processing Record 25 of Set 11 | le pradet
# Processing Record 26 of Set 11 | christchurch
# Processing Record 27 of Set 11 | ballina
# Processing Record 28 of Set 11 | bahir dar
# Processing Record 29 of Set 11 | palauig
# Processing Record 30 of Set 11 | arsk
# Processing Record 31 of Set 11 | roald
# Processing Record 32 of Set 11 | angra
# City not found. Skipping...
# Processing Record 33 of Set 11 | guanare
# Processing Record 34 of Set 11 | arlit
# Processing Record 35 of Set 11 | puerto escondido
# Processing Record 36 of Set 11 | casambalangan
# Processing Record 37 of Set 11 | twistringen
# Processing Record 38 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 11 | morondava
# Processing Record 40 of Set 11 | key west
# Processing Record 41 of Set 11 | ucluelet
# Processing Record 42 of Set 11 | kesinga
# Processing Record 43 of Set 11 | dandong
# Processing Record 44 of Set 11 | the valley
# Processing Record 45 of Set 11 | andenes
# Processing Record 46 of Set 11 | grand haven
# Processing Record 47 of Set 11 | kalemie
# Processing Record 48 of Set 11 | altay
# Processing Record 49 of Set 11 | buchanan
# Processing Record 50 of Set 11 | shingu
# Processing Record 1 of Set 12 | kaitangata
# Processing Record 2 of Set 12 | antofagasta
# Processing Record 3 of Set 12 | lobito
# Processing Record 4 of Set 12 | camabatela
# Processing Record 5 of Set 12 | nyurba
# Processing Record 6 of Set 12 | port macquarie
# Processing Record 7 of Set 12 | tempio pausania
# Processing Record 8 of Set 12 | santiago del estero
# Processing Record 9 of Set 12 | narwar
# Processing Record 10 of Set 12 | kapit
# Processing Record 11 of Set 12 | fort nelson
# Processing Record 12 of Set 12 | pilani
# Processing Record 13 of Set 12 | mount pleasant
# Processing Record 14 of Set 12 | axim
# Processing Record 15 of Set 12 | quesnel
# Processing Record 16 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 12 | henties bay
# Processing Record 18 of Set 12 | danane
# Processing Record 19 of Set 12 | richards bay
# Processing Record 20 of Set 12 | mariental
# Processing Record 21 of Set 12 | kamyaran
# Processing Record 22 of Set 12 | prince rupert
# Processing Record 23 of Set 12 | imeni poliny osipenko
# Processing Record 24 of Set 12 | beyneu
# Processing Record 25 of Set 12 | nortelandia
# Processing Record 26 of Set 12 | puerto maldonado
# Processing Record 27 of Set 12 | tuy hoa
# Processing Record 28 of Set 12 | salinas
# Processing Record 29 of Set 12 | puerto madryn
# Processing Record 30 of Set 12 | santa luzia
# Processing Record 31 of Set 12 | buncrana
# Processing Record 32 of Set 12 | metro
# Processing Record 33 of Set 12 | shizunai
# Processing Record 34 of Set 12 | ruteng
# Processing Record 35 of Set 12 | broome
# Processing Record 36 of Set 12 | mareeba
# Processing Record 37 of Set 12 | hualmay
# Processing Record 38 of Set 12 | yakeshi
# Processing Record 39 of Set 12 | naze
# Processing Record 40 of Set 12 | labuan
# Processing Record 41 of Set 12 | cintalapa
# Processing Record 42 of Set 12 | mangochi
# Processing Record 43 of Set 12 | tagab
# Processing Record 44 of Set 12 | makakilo city
# Processing Record 45 of Set 12 | qaqortoq
# Processing Record 46 of Set 12 | yinchuan
# Processing Record 47 of Set 12 | tuim
# Processing Record 48 of Set 12 | kasongo-lunda
# Processing Record 49 of Set 12 | dudinka
# Processing Record 50 of Set 12 | biak
# Processing Record 1 of Set 13 | rabo de peixe
# Processing Record 2 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 4 of Set 13 | guayaramerin
# Processing Record 5 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 13 | makaryev
# Processing Record 7 of Set 13 | karwar
# Processing Record 8 of Set 13 | ust-koksa
# Processing Record 9 of Set 13 | itarema
# Processing Record 10 of Set 13 | pilar
# Processing Record 11 of Set 13 | rimouski
# Processing Record 12 of Set 13 | kamyzyak
# Processing Record 13 of Set 13 | carndonagh
# Processing Record 14 of Set 13 | smidovich
# Processing Record 15 of Set 13 | saint-georges
# Processing Record 16 of Set 13 | coquimbo
# Processing Record 17 of Set 13 | baykit
# Processing Record 18 of Set 13 | nhulunbuy
# Processing Record 19 of Set 13 | adre
# Processing Record 20 of Set 13 | labuhan
# Processing Record 21 of Set 13 | nouakchott
# Processing Record 22 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 13 | saldanha
# Processing Record 24 of Set 13 | shiraz
# Processing Record 25 of Set 13 | manturovo
# Processing Record 26 of Set 13 | naryan-mar
# Processing Record 27 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 28 of Set 13 | bolgar
# Processing Record 29 of Set 13 | stornoway
# Processing Record 30 of Set 13 | winneba
# Processing Record 31 of Set 13 | pacifica
# Processing Record 32 of Set 13 | verkhoyansk
# Processing Record 33 of Set 13 | lebedinyy
# Processing Record 34 of Set 13 | vaterstetten
# Processing Record 35 of Set 13 | melo
# Processing Record 36 of Set 13 | thinadhoo
# Processing Record 37 of Set 13 | portland
# Processing Record 38 of Set 13 | malanje
# Processing Record 39 of Set 13 | muros
# Processing Record 40 of Set 13 | iquique
# Processing Record 41 of Set 13 | moerai
# Processing Record 42 of Set 13 | baiquan
# Processing Record 43 of Set 13 | bacolod
# Processing Record 44 of Set 13 | matagami
# Processing Record 45 of Set 13 | isla vista
# Processing Record 46 of Set 13 | linhares
# Processing Record 47 of Set 13 | trinidad
# Processing Record 48 of Set 13 | cap malheureux
# Processing Record 49 of Set 13 | baindur
# Processing Record 50 of Set 13 | port blair
# Processing Record 1 of Set 14 | kamalpur
# Processing Record 2 of Set 14 | orlik
# Processing Record 3 of Set 14 | mao
# Processing Record 4 of Set 14 | kununurra
# Processing Record 5 of Set 14 | tres lagoas
# Processing Record 6 of Set 14 | saint anthony
# Processing Record 7 of Set 14 | montepuez
# Processing Record 8 of Set 14 | sursk
# Processing Record 9 of Set 14 | gushikawa
# Processing Record 10 of Set 14 | siparia
# Processing Record 11 of Set 14 | zhanakorgan
# Processing Record 12 of Set 14 | say
# Processing Record 13 of Set 14 | finnsnes
# Processing Record 14 of Set 14 | taphan hin
# Processing Record 15 of Set 14 | liverpool
# Processing Record 16 of Set 14 | norton
# Processing Record 17 of Set 14 | paramirim
# Processing Record 18 of Set 14 | karpuninskiy
# City not found. Skipping...
# Processing Record 19 of Set 14 | crnici
# Processing Record 20 of Set 14 | soyo
# Processing Record 21 of Set 14 | tshikapa
# Processing Record 22 of Set 14 | kapoeta
# Processing Record 23 of Set 14 | egvekinot
# Processing Record 24 of Set 14 | pisco
# Processing Record 25 of Set 14 | banswara
# Processing Record 26 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 14 | madera
# Processing Record 28 of Set 14 | mangrol
# Processing Record 29 of Set 14 | saint-pierre
# Processing Record 30 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 31 of Set 14 | pauini
# Processing Record 32 of Set 14 | tsabong
# Processing Record 33 of Set 14 | nara
# Processing Record 34 of Set 14 | kshenskiy
# Processing Record 35 of Set 14 | sibenik
# Processing Record 36 of Set 14 | soskovo
# Processing Record 37 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 38 of Set 14 | soe
# Processing Record 39 of Set 14 | rorvik
# Processing Record 40 of Set 14 | abu dhabi
# Processing Record 41 of Set 14 | wiwili
# Processing Record 42 of Set 14 | nanakuli
# Processing Record 43 of Set 14 | rantepao
# Processing Record 44 of Set 14 | marzuq
# Processing Record 45 of Set 14 | yulara
# Processing Record 46 of Set 14 | maxixe
# Processing Record 47 of Set 14 | eureka
# Processing Record 48 of Set 14 | nantucket
# Processing Record 49 of Set 14 | hearst
# Processing Record 50 of Set 14 | leirvik
# Processing Record 1 of Set 15 | xiongshi
# City not found. Skipping...
# Processing Record 2 of Set 15 | bilibino
# Processing Record 3 of Set 15 | maple creek
# Processing Record 4 of Set 15 | ganzhou
# Processing Record 5 of Set 15 | george
# Processing Record 6 of Set 15 | pontes e lacerda
# Processing Record 7 of Set 15 | yerbogachen
# Processing Record 8 of Set 15 | roswell
# Processing Record 9 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 15 | gambiran
# Processing Record 11 of Set 15 | tiarei
# Processing Record 12 of Set 15 | krasnoturansk
# Processing Record 13 of Set 15 | ballymena
# Processing Record 14 of Set 15 | marawi
# Processing Record 15 of Set 15 | ostrovnoy
# Processing Record 16 of Set 15 | porto nacional
# Processing Record 17 of Set 15 | pemangkat
# Processing Record 18 of Set 15 | viedma
# Processing Record 19 of Set 15 | guaratuba
# Processing Record 20 of Set 15 | zigong
# Processing Record 21 of Set 15 | udachnyy
# Processing Record 22 of Set 15 | qasigiannguit
# Processing Record 23 of Set 15 | kalabo
# Processing Record 24 of Set 15 | binga
# Processing Record 25 of Set 15 | raton
# Processing Record 26 of Set 15 | sambava
# Processing Record 27 of Set 15 | north bend
# Processing Record 28 of Set 15 | emba
# Processing Record 29 of Set 15 | blackfoot
# Processing Record 30 of Set 15 | khuzhir
# Processing Record 31 of Set 15 | qiyang
# Processing Record 32 of Set 15 | grand gaube
# Processing Record 33 of Set 15 | ust-ishim
# Processing Record 34 of Set 15 | santa rosa
# Processing Record 35 of Set 15 | harrison
# Processing Record 36 of Set 15 | chicama
# Processing Record 37 of Set 15 | thurso
# Processing Record 38 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 39 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 40 of Set 15 | tiznit
# Processing Record 41 of Set 15 | macamic
# Processing Record 42 of Set 15 | kikwit
# Processing Record 43 of Set 15 | vao
# Processing Record 44 of Set 15 | belmonte
# Processing Record 45 of Set 15 | saint paul
# Processing Record 46 of Set 15 | mankera
# Processing Record 47 of Set 15 | grindavik
# Processing Record 48 of Set 15 | litoral del san juan
# City not found. Skipping...
# Processing Record 49 of Set 15 | sept-iles
# Processing Record 50 of Set 15 | hami
# Processing Record 1 of Set 16 | chimalpa
# Processing Record 2 of Set 16 | mogadishu
# Processing Record 3 of Set 16 | bobo dioulasso
# Processing Record 4 of Set 16 | gondanglegi
# Processing Record 5 of Set 16 | pierre
# Processing Record 6 of Set 16 | alofi
# Processing Record 7 of Set 16 | tambacounda
# Processing Record 8 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 16 | santiago de cao
# Processing Record 10 of Set 16 | krasnoselkup
# Processing Record 11 of Set 16 | matara
# Processing Record 12 of Set 16 | camacha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nanortalik      GL  60.1432  -45.2371     31.10        93           2
# 1          Hilo      US  19.7297 -155.0900     73.40        64          75
# 2      Cidreira      BR -30.1811  -50.2056     72.90        91         100
# 3  Port Augusta      AU -32.5000  137.7667     82.99        65           0
# 4       Rikitea      PF -23.1203 -134.9692     80.01        69          87
# 5     Jamestown      US  42.0970  -79.2353     17.01        79          90
# 6          Hede      CN  33.7681  120.2517     46.17        50           0
# 7        Zaraza      VE   9.3503  -65.3245     70.68        92          52
# 8          Poum      NC -20.2333  164.0167     80.11        79          98
# 9          Chuy      UY -33.6971  -53.4616     66.33        83          73
#
#    Wind Speed Current Description
# 0       12.57           clear sky
# 1        9.08          light rain
# 2       15.17     overcast clouds
# 3       21.85           clear sky
# 4        4.25          light rain
# 5       18.41          light snow
# 6       12.84           clear sky
# 7        4.23       broken clouds
# 8       11.27     overcast clouds
# 9        8.05       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
